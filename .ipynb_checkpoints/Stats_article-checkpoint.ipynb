# %%
d <- read.table("aneurysm.csv", header=T, sep=";", stringsAsFactors=T) #on charge les données

# %%
head(d) #on regarde les variables d'analyse des données et leur type
# Out:
#   country gender aneurysm bmi    risk
# 1 Vietnam M      21       21.094 0
# 2 Vietnam M      27       19.031 0
# 3 Vietnam M      28       20.313 0
# 4 Vietnam F      33       17.778 0
# 5 France  F      34       21.604 0
# 6 Vietnam F      35       21.096 0

# %%
dim(d) #on regarde la dimension de notre échantillon de données, ici de 209 individus et de 5 paramètres (country, gender, aneurysm, bmi et risk)
# Out:
# [1] 209   5

# %%
summary(d) #on regarde les stats associées aux variables pour voir si nos données sont par exemple, d'un effectif suffisant
# Out:
#     country    gender     aneurysm           bmi             risk
#  France : 99   F: 51   Min.   : 21.00   Min.   :13.33   Min.   :0.000
#  Vietnam:110   M:158   1st Qu.: 37.00   1st Qu.:19.23   1st Qu.:1.000
#                        Median : 46.00   Median :22.21   Median :1.000
#                        Mean   : 47.57   Mean   :22.76   Mean   :1.388
#                        3rd Qu.: 55.00   3rd Qu.:26.37   3rd Qu.:2.000
#                        Max.   :102.00   Max.   :36.16   Max.   :5.000

# %%
hist(d$aneurysm, nclass=50) #nous regardons l'histo de l'âge de première prise en charge
# Out:
# Plot with title "Histogram of d$aneurysm"

# %%
hist(d$bmi, nclass=50) #histo de l'IMC
# Out:
# Plot with title "Histogram of d$bmi"

# %%
install.packages("mclust", dependencies=T) #installation du package Mclust pour effectuer une classification
# Out:
# Les packages binaires t'el'echarg'es sont dans
# 	/var/folders/lb/qcvqx8917_7gvcqgrtn8t4n80000gn/T//RtmpAhgpHd/downloaded_packages

# %%
library("mclust") #visualiser si la libraire MClust a bien été installée

# %%
d.mc.b<- Mclust(d$bmi, G=3:7) #mélange gaussien selon la variable IMC pour trouver des proba d'appartenance à un groupe

# %%
d.mc.b$G #visualisation du nombre de groupes trouvés à partir de l'IMC
# Out:
# [1] 3

# %%
plot(x=d$bmi, pch = 20, col = d.mc.b$classification) #tracé du graphique des points de couleurs différentes selon les classifications selon BMI
# Out:
# plot without title

# %%
d.mc.a<- Mclust(d$aneurysm, G=3:7) #mélange gaussien selon la variable âge pour trouver des proba d'appartenance à un groupe

# %%
d.mc.a$G #visualisation du nombre de groupes trouvés à partir de l'âge
# Out:
# [1] 3

# %%
plot(x=d$aneurysm, pch = 20, col = d.mc.a$classification) #tracé du graphique des points de couleurs différentes selon les classifications selon âge
# Out:
# plot without title

# %%
lm1=with(d, lm(d$bmi ~ as.factor(d$country) + as.factor(d$gender) +as.factor(d$aneurysm) + as.factor(d$risk)))

# %%
anova(lm1)
# Out:
#                       Df  Sum Sq     Mean Sq     F value     Pr(>F)
# as.factor(d$country)    1 1898.96440 1898.964405 216.4664403 9.203646e-31
# as.factor(d$gender)     1   63.93458   63.934576   7.2880197 7.749966e-03
# as.factor(d$aneurysm)  53  434.29304    8.194208   0.9340729 6.037502e-01
# as.factor(d$risk)       5  139.81997   27.963994   3.1876671 9.197560e-03
# Residuals             148 1298.33859    8.772558          NA           NA

# %%
d.mc<- Mclust(d$risk, G=3:7)

# %%
d.mc$G
# Out:
# [1] 4

# %%
plot(x=d$risk, pch=20, col = d.mc$classification)
# Out:
# plot without title

# %%
d.mc.b$G
# Out:
# [1] 4

# %%
# Out:
# Error in eval(expr, envir, enclos): objet 'd.mc.b' introuvable
# Traceback:
#
# 1. plot(x = d$bmi, col = d.mc.b$classification)
# 2. plot.default(x = d$bmi, col = d.mc.b$classification)
# 3. plot.xy(xy, type, ...)
# plot without title

# %%
lm11=with(d, lm(d$risk ~ as.factor(d$country) + as.factor(d$gender) +as.factor(d$aneurysm) + as.factor(d$bmi)))

# %%
anova(lm11)
# Out:
#                       Df  Sum Sq     Mean Sq    F value   Pr(>F)
# as.factor(d$country)    1  11.644019 11.6440191 14.810305 0.002706893
# as.factor(d$gender)     1  14.866866 14.8668665 18.909521 0.001158255
# as.factor(d$aneurysm)  53  44.558680  0.8407298  1.069344 0.485073339
# as.factor(d$bmi)      142 129.889773  0.9147167  1.163450 0.418611987
# Residuals              11   8.648317  0.7862106        NA          NA

# %%
plot(x=d$bmi, y=d$risk, pch=20, col = d.mc$classification)
# Out:
# plot without title

# %%
table(d$bmi, d.mc$classification)
# Out:
#
#          1 2 3 4
#   13.333 1 0 0 0
#   14.533 0 0 1 0
#   14.568 0 0 0 1
#   14.984 0 0 1 0
#   15.111 1 0 0 0
#   15.427 0 1 0 0
#   15.556 0 0 1 0
#   15.582 0 1 0 0
#   16.004 0 1 0 0
#   16.228 0 1 0 0
#   16.327 0 0 1 0
#   16.406 0 1 1 0
#   16.529 0 1 0 0
#   16.649 1 0 0 0
#   16.947 1 0 0 0
#   17.01  0 0 1 0
#   17.087 0 1 0 0
#   17.425 0 1 0 0
#   17.567 0 1 0 0
#   17.71  1 0 0 0
#   17.778 2 1 0 0
#   17.782 0 0 1 0
#   17.823 1 0 0 0
#   17.857 0 2 0 0
#   17.993 0 0 1 0
#   18.07  0 1 0 0
#   18.359 0 1 0 0
#   18.365 1 0 1 0
#   18.491 0 1 0 0
#   18.591 0 1 0 0
#   18.667 0 1 0 0
#   18.685 1 0 0 0
#   18.73  0 0 1 0
#   18.75  1 2 0 0
#   18.809 0 0 1 0
#   18.929 0 1 0 0
#   18.975 0 2 0 0
#   19.031 1 0 2 0
#   19.1   0 1 0 0
#   19.111 0 2 0 0
#   19.141 0 1 0 0
#   19.228 0 1 0 0
#   19.477 1 0 0 0
#   19.487 0 1 0 0
#   19.531 0 2 0 0
#   19.694 0 1 0 0
#   19.814 0 1 0 0
#   19.835 0 1 0 0
#   19.837 0 1 0 0
#   20.029 0 0 1 0
#   20.077 0 0 1 0
#   20.173 0 0 1 0
#   20.196 0 0 0 1
#   20.313 1 2 0 0
#   20.576 1 0 0 0
#   20.761 0 1 0 1
#   20.776 0 1 0 0
#   20.812 0 1 1 0
#   20.83  0 0 1 0
#   20.957 0 1 0 0
#   20.988 0 1 0 0
#   21.094 2 2 1 0
#   21.096 1 0 0 0
#   21.231 0 1 0 0
#   21.259 0 0 1 0
#   21.338 0 0 1 0
#   21.504 0 1 0 0
#   21.535 0 0 0 1
#   21.604 1 0 0 0
#   21.605 0 0 0 1
#   21.799 0 1 0 0
#   21.83  0 0 1 0
#   21.857 1 0 0 0
#   21.875 0 1 0 0
#   21.914 1 0 0 0
#   21.952 0 1 0 0
#   22.039 0 1 1 0
#   22.206 1 1 6 2
#   22.232 1 0 0 0
#   22.308 0 0 1 0
#   22.395 0 1 0 0
#   22.491 0 2 0 1
#   22.583 1 0 0 0
#   22.724 0 1 0 0
#   22.79  0 0 1 0
#   22.862 1 0 0 0
#   22.985 0 1 0 0
#   23.438 1 1 0 0
#   23.548 1 0 0 0
#   23.661 0 1 0 0
#   23.671 0 0 1 0
#   23.735 0 0 1 0
#   23.739 0 0 1 0
#   23.875 1 0 0 0
#   23.922 1 0 0 0
#   23.939 0 0 1 0
#   24.005 0 1 0 0
#   24.035 2 1 0 0
#   24.152 1 0 0 0
#   24.221 0 1 0 0
#   24.302 1 0 0 0
#   24.344 1 0 0 0
#   24.447 0 0 1 0
#   24.465 0 1 0 0
#   24.772 0 0 1 0
#   24.802 0 0 0 1
#   24.897 0 1 0 0
#   24.913 0 1 0 0
#   25.1   0 0 1 0
#   25.344 0 1 0 0
#   25.393 0 1 0 0
#   25.469 0 0 1 0
#   25.481 0 1 0 0
#   25.594 0 0 1 0
#   25.763 1 0 0 0
#   25.766 0 0 0 1
#   25.909 0 1 0 0
#   25.911 1 0 0 0
#   25.952 0 0 1 0
#   26.174 1 0 0 0
#   26.219 1 0 0 0
#   26.366 0 2 0 0
#   26.398 0 0 1 0
#   26.563 0 3 1 1
#   26.573 0 1 0 0
#   26.61  0 1 0 0
#   26.673 0 1 0 0
#   26.675 1 0 0 0
#   26.704 0 0 1 1
#   26.73  0 1 0 1
#   26.795 0 0 1 0
#   26.927 0 0 1 0
#   26.99  1 0 0 0
#   27.054 0 0 1 0
#   27.084 0 0 0 1
#   27.111 0 0 1 0
#   27.143 0 0 0 1
#   27.344 0 1 2 0
#   27.38  0 0 1 0
#   27.414 0 0 0 1
#   27.441 0 0 0 1
#   27.682 0 0 1 0
#   28.056 0 0 0 1
#   28.345 0 1 0 0
#   28.408 0 1 0 0
#   28.732 0 0 1 0
#   29.066 0 0 1 0
#   29.07  0 0 0 1
#   29.297 0 1 0 0
#   29.321 0 0 0 1
#   29.385 0 0 0 1
#   29.395 0 1 0 0
#   29.411 0 0 0 1
#   29.412 0 0 0 1
#   29.727 0 0 1 0
#   29.758 0 0 0 1
#   30.247 0 0 1 0
#   31.179 0 0 0 1
#   31.378 0 0 1 0
#   31.637 0 0 0 1
#   31.834 0 0 1 0
#   32     0 0 0 1
#   33.081 0 0 1 0
#   33.897 0 0 1 0
#   36.157 0 0 1 0
